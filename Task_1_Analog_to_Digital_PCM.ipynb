# %% [markdown]
# #### Name: Md. Abid Ullah Muhib
#
# #### Reg. No.: 2020331089
#
# ##### Session : 2020-2021
#
# ##### Computer Science & Engineering, SUST
#
# <hr />

# %% [markdown]
# # Analog to Digital Conversion Using PCM
#
# This notebook simulates conversion of an analog signal into a digital signal using Python. The steps involved are :
# generating an analog signal, sampling, quantizing, encoding, and visualizing each stage of the conversion.
#
# ## 1. Generating an Analog Signal
#
# Generating an analog signal, in this case it is a sine wave.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
sampling_rate = 1000  # Hz
t = np.linspace(0, 1, sampling_rate)
frequency = 5  # Hz
amplitude = 1

# Create the analog signal (sine wave)
analog_signal = amplitude * np.sin(2 * np.pi * frequency * t)

# Visualize the analog signal
plt.figure(figsize=(10, 4))
plt.plot(t, analog_signal, label='Analog Signal')
plt.xlabel('Time [sec]')
plt.ylabel('Amplitude')
plt.title('Analog Signal')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 2. Sampling the Signal
#
# We sample the analog signal at discrete intervals.

# %%
# Sampling parameters
sampling_interval = 0.01  # seconds (sampling every 10 ms)
sample_times = np.arange(0, 1, sampling_interval)

# Sampled signal
sampled_signal = amplitude * np.sin(2 * np.pi * frequency * sample_times)

# Visualize the sampled signal
plt.figure(figsize=(10, 4))
plt.plot(t, analog_signal, label='Analog Signal')
plt.stem(sample_times, sampled_signal, 'r', markerfmt='ro', basefmt=" ", label='Sampled Signal')
plt.xlabel('Time [sec]')
plt.ylabel('Amplitude')
plt.title('Sampled Signal')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 3. Quantizing the Signal
#
# Quantize the sampled signal to discrete levels.

# %%
# Quantization parameters
num_levels = 16  # Number of quantization levels
quantized_signal = np.round((sampled_signal + amplitude) * (num_levels - 1) / (2 * amplitude)) * (2 * amplitude / (num_levels - 1)) - amplitude

# Visualize the quantized signal
plt.figure(figsize=(10, 4))
plt.plot(t, analog_signal, label='Analog Signal')
plt.stem(sample_times, quantized_signal, 'g', markerfmt='go', basefmt=" ", label='Quantized Signal')
plt.xlabel('Time [sec]')
plt.ylabel('Amplitude')
plt.title('Quantized Signal')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 4. Encoding the Signal
#
# Encode the quantized signal into a binary format

# %%
# Binary encoding function
def binary_encode(value, num_bits):
    value += amplitude  # Shift to positive range
    max_value = 2 * amplitude
    scaled_value = int(value / max_value * (2**num_bits - 1))
    return format(scaled_value, f'0{num_bits}b')

# Encode the quantized signal
num_bits = 4  # Number of bits per sample
encoded_signal = [binary_encode(val, num_bits) for val in quantized_signal]

# Display the encoded signal
for time, sample, encoded in zip(sample_times, quantized_signal, encoded_signal):
    print(f"Time: {time:.2f}s, Sample: {sample:.2f}, Encoded: {encoded}")

# Visualize the encoded signal (binary representation)
plt.figure(figsize=(10, 4))
plt.plot(t, analog_signal, label='Analog Signal')
plt.stem(sample_times, quantized_signal, 'b', markerfmt='bo', basefmt=" ", label='Encoded Signal')
for i, txt in enumerate(encoded_signal):
    plt.annotate(txt, (sample_times[i], quantized_signal[i]), textcoords="offset points", xytext=(0,10), ha='center')
plt.xlabel('Time [sec]')
plt.ylabel('Amplitude')
plt.title('Encoded Signal')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Time: 0.00s, Sample: 0.07, Encoded: 1000
# Time: 0.01s, Sample: 0.33, Encoded: 1010
# Time: 0.02s, Sample: 0.60, Encoded: 1100
# Time: 0.03s, Sample: 0.87, Encoded: 1110
# Time: 0.04s, Sample: 1.00, Encoded: 1111
# Time: 0.05s, Sample: 1.00, Encoded: 1111
# Time: 0.06s, Sample: 1.00, Encoded: 1111
# Time: 0.07s, Sample: 0.87, Encoded: 1110
# Time: 0.08s, Sample: 0.60, Encoded: 1100
# Time: 0.09s, Sample: 0.33, Encoded: 1010
# Time: 0.10s, Sample: 0.07, Encoded: 1000
# Time: 0.11s, Sample: -0.33, Encoded: 0101
# Time: 0.12s, Sample: -0.60, Encoded: 0011
# Time: 0.13s, Sample: -0.87, Encoded: 0000
# Time: 0.14s, Sample: -1.00, Encoded: 0000
# Time: 0.15s, Sample: -1.00, Encoded: 0000
# Time: 0.16s, Sample: -1.00, Encoded: 0000
# Time: 0.17s, Sample: -0.87, Encoded: 0000
# Time: 0.18s, Sample: -0.60, Encoded: 0011
# Time: 0.19s, Sample: -0.33, Encoded: 0101
# Time: 0.20s, Sample: -0.07, Encoded: 0111
# Time: 0.21s, Sample: 0.33, Encoded: 1010
# Time: 0.22s, Sample: 0.60, Encoded: 1100
# Time: 0.23s, Sample: 0.87, Encoded: 1110
# Time: 0.24s, Sample: 1.00, Encoded: 1111
# Time: 0.25s, Sample: 1.00, Encoded: 1111
# Time: 0.26s, Sample: 1.00, Encoded: 1111
# Time: 0.27s, Sample: 0.87, Encoded: 1110
# Time: 0.28s, Sample: 0.60, Encoded: 1100
# Time: 0.29s, Sample: 0.33, Encoded: 1010
# Time: 0.30s, Sample: 0.07, Encoded: 1000
# Time: 0.31s, Sample: -0.33, Encoded: 0101
# Time: 0.32s, Sample: -0.60, Encoded: 0011
# Time: 0.33s, Sample: -0.87, Encoded: 0000
# Time: 0.34s, Sample: -1.00, Encoded: 0000
# Time: 0.35s, Sample: -1.00, Encoded: 0000
# Time: 0.36s, Sample: -1.00, Encoded: 0000
# Time: 0.37s, Sample: -0.87, Encoded: 0000
# Time: 0.38s, Sample: -0.60, Encoded: 0011
# Time: 0.39s, Sample: -0.33, Encoded: 0101
# Time: 0.40s, Sample: -0.07, Encoded: 0111
# Time: 0.41s, Sample: 0.33, Encoded: 1010
# Time: 0.42s, Sample: 0.60, Encoded: 1100
# Time: 0.43s, Sample: 0.87, Encoded: 1110
# Time: 0.44s, Sample: 1.00, Encoded: 1111
# Time: 0.45s, Sample: 1.00, Encoded: 1111
# Time: 0.46s, Sample: 1.00, Encoded: 1111
# Time: 0.47s, Sample: 0.87, Encoded: 1110
# Time: 0.48s, Sample: 0.60, Encoded: 1100
# Time: 0.49s, Sample: 0.33, Encoded: 1010
# Time: 0.50s, Sample: 0.07, Encoded: 1000
# Time: 0.51s, Sample: -0.33, Encoded: 0101
# Time: 0.52s, Sample: -0.60, Encoded: 0011
# Time: 0.53s, Sample: -0.87, Encoded: 0000
# Time: 0.54s, Sample: -1.00, Encoded: 0000
# Time: 0.55s, Sample: -1.00, Encoded: 0000
# Time: 0.56s, Sample: -1.00, Encoded: 0000
# Time: 0.57s, Sample: -0.87, Encoded: 0000
# Time: 0.58s, Sample: -0.60, Encoded: 0011
# Time: 0.59s, Sample: -0.33, Encoded: 0101
# Time: 0.60s, Sample: -0.07, Encoded: 0111
# Time: 0.61s, Sample: 0.33, Encoded: 1010
# Time: 0.62s, Sample: 0.60, Encoded: 1100
# Time: 0.63s, Sample: 0.87, Encoded: 1110
# Time: 0.64s, Sample: 1.00, Encoded: 1111
# Time: 0.65s, Sample: 1.00, Encoded: 1111
# Time: 0.66s, Sample: 1.00, Encoded: 1111
# Time: 0.67s, Sample: 0.87, Encoded: 1110
# Time: 0.68s, Sample: 0.60, Encoded: 1100
# Time: 0.69s, Sample: 0.33, Encoded: 1010
# Time: 0.70s, Sample: -0.07, Encoded: 0111
# Time: 0.71s, Sample: -0.33, Encoded: 0101
# Time: 0.72s, Sample: -0.60, Encoded: 0011
# Time: 0.73s, Sample: -0.87, Encoded: 0000
# Time: 0.74s, Sample: -1.00, Encoded: 0000
# Time: 0.75s, Sample: -1.00, Encoded: 0000
# Time: 0.76s, Sample: -1.00, Encoded: 0000
# Time: 0.77s, Sample: -0.87, Encoded: 0000
# Time: 0.78s, Sample: -0.60, Encoded: 0011
# Time: 0.79s, Sample: -0.33, Encoded: 0101
# Time: 0.80s, Sample: -0.07, Encoded: 0111
# Time: 0.81s, Sample: 0.33, Encoded: 1010
# Time: 0.82s, Sample: 0.60, Encoded: 1100
# Time: 0.83s, Sample: 0.87, Encoded: 1110
# Time: 0.84s, Sample: 1.00, Encoded: 1111
# Time: 0.85s, Sample: 1.00, Encoded: 1111
# Time: 0.86s, Sample: 1.00, Encoded: 1111
# Time: 0.87s, Sample: 0.87, Encoded: 1110
# Time: 0.88s, Sample: 0.60, Encoded: 1100
# Time: 0.89s, Sample: 0.33, Encoded: 1010
# Time: 0.90s, Sample: 0.07, Encoded: 1000
# Time: 0.91s, Sample: -0.33, Encoded: 0101
# Time: 0.92s, Sample: -0.60, Encoded: 0011
# Time: 0.93s, Sample: -0.87, Encoded: 0000
# Time: 0.94s, Sample: -1.00, Encoded: 0000
# Time: 0.95s, Sample: -1.00, Encoded: 0000
# Time: 0.96s, Sample: -1.00, Encoded: 0000
# Time: 0.97s, Sample: -0.87, Encoded: 0000
# Time: 0.98s, Sample: -0.60, Encoded: 0011
# Time: 0.99s, Sample: -0.33, Encoded: 0101

# %% [markdown]
# ## 5. Decoding and Visualizing the Digital Signal
#
# Decode the binary encoded signal and visualize the resulting digital waveform.

# %%
digital_time = np.repeat(sample_times, num_bits + 1)  # +1 to create steps
digital_signal = []

for encoded in encoded_signal:
    for bit in encoded:
        digital_signal.extend([int(bit)] * (num_bits + 1))

# Trim the digital_signal to the length of digital_time
digital_signal = digital_signal[:len(digital_time)]

# Visualize the digital form of the encoded signal
plt.figure(figsize=(10, 4))
plt.step(digital_time, digital_signal, where='post', label='Digital Signal')
plt.xlabel('Time [sec]')
plt.ylabel('Digital Signal')
plt.title('Digital Form of the Encoded Signal')
plt.legend()
plt.grid(True)
plt.show()
